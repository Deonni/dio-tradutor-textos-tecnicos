# %%
# !pip install -U langchain-openai
import requests
from bs4 import BeautifulSoup
def extract_text_from_url(url):
  response = requests.get(url)
  if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")
    for script_or_style in soup(['script', 'style']):
      script_or_style.extract()
    text = soup.get_text()
    # Clean the text: remove extra newlines and strip whitespace
    clean_text = '\n'.join(line.strip() for line in text.splitlines() if line.strip())
    return clean_text
  else:
    print(f"Failed to fetch the URL. Status code: {response.status_code}")
    return None

extract_text_from_url("https://dev.to/kenakamu/azure-open-ai-in-vnet-3alo")
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-1.1.7-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.6 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (1.2.6)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (2.14.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (0.6.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (0.13.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.109.1->langchain-openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain-openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.6->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-openai) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.6->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.6->langchain-openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.6->langchain-openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.5.0)
# Downloading langchain_openai-1.1.7-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: langchain-openai
# Successfully installed langchain-openai-1.1.7
# "Azure Open AI in VNet - DEV Community\nForem Feed\nFollow new Subforems to improve your feed\nDEV Community\nFollow\nA space to discuss and keep up software development and manage your software career\nFuture\nFollow\nNews and discussion of science and technology such as AI, VR, cryptocurrency, quantum computing, and more.\nOpen Forem\nFollow\nA general discussion space for the Forem community. If it doesn't have a home elsewhere, it belongs here\nGamers Forem\nFollow\nAn inclusive community for gaming enthusiasts\nMusic Forem\nFollow\nFrom composing and gigging to gear, hot music takes, and everything in between.\nVibe Coding Forem\nFollow\nDiscussing AI software development, and showing off what we're building.\nPopcorn Movies and TV\nFollow\nMovie and TV enthusiasm, criticism and everything in-between.\nDUMB DEV Community\nFollow\nMemes and software development shitposting\nDesign Community\nFollow\nWeb design, graphic design and everything in-between\nSecurity Forem\nFollow\nYour central hub for all things security. From ethical hacking and CTFs to GRC and career development, for beginners and pros alike\nGolf Forem\nFollow\nA community of golfers and golfing enthusiasts\nCrypto Forem\nFollow\nA collaborative community for all things Crypto—from Bitcoin to protocol development and DeFi to NFTs and market analysis.\nParenting\nFollow\nA place for parents to the share the joys, challenges, and wisdom that come from raising kids. We're here for them and for each other.\nForem Core\nFollow\nDiscussing the core forem open source software project — features, bugs, performance, self-hosting.\nMaker Forem\nFollow\nA community for makers, hobbyists, and professionals to discuss Arduino, Raspberry Pi, 3D printing, and much more.\nHMPL.js Forem\nFollow\nFor developers using HMPL.js to build fast, lightweight web apps. A space to share projects, ask questions, and discuss server-driven templating\nDropdown menu\nDropdown menu\nSkip to content\nNavigation menu\nSearch\nPowered by Algolia\nSearch\nLog in\nCreate account\nDEV Community\nClose\nAdd reaction\nLike\nUnicorn\nExploding Head\nRaised Hands\nFire\nJump to Comments\nSave\nBoost\nMore...\nCopy link\nCopy link\nCopied to Clipboard\nShare to X\nShare to LinkedIn\nShare to Facebook\nShare to Mastodon\nReport Abuse\nKenichiro Nakamura\nPosted on Oct 12, 2023\nAzure Open AI in VNet\n#azure\n#openai\n#security\nGPT models are hosted in multiple service vendor at the moment, and Microsoft Azure is one of them.\nEven though the models themselves are the same, there are many differences including:\ncost\nfunctionalities\ntype of models and versions\ngeo location\nsecurity\nsupport\netc.\nOne of the most important aspects when we use it in an Enterprise Environment is, of course, security.\nBy using Azure network security features with Azure Open AI, customers can consume the Open AI service from and within the VNet, therefore no information is flowing in public.\nSample Deployment\nAzure Sample repo provides a sample bicep files to deploy Azure Open AI into VNet environment.\nGitHub: openai-enterprise-iac\nThe key features the bicep uses are:\nVNet\nVNet integration for Web App\nPrivate Endpoint for Azure Open AI\nPrivate Endpoint for Cognitive Search\nPrivate DNS Zone\nBy using these features, all the outbound traffic from the Web App only routed inside the VNet and all the names are resolved into private IP addresses. Open AI and Cognitive Search shut down the public IP address, thus there is not public interface endpoint available anymore.\nDeploy\nThe bicep file will deploy following Azure Resources.\nLet's deploy and confirm how it works. I create a resource group in East US region for my own test.\ngit clone https://github.com/Azure-Samples/openai-enterprise-iac\ncd openai-enterprise-iac\naz group create -n openaitest -l eastus\naz deployment group create -g openaitest -f .\\infra\\main.bicep\nEnter fullscreen mode\nExit fullscreen mode\nOnce I run the commend above, I see the depl ...

# %%
from langchain_openai.chat_models.azure import AzureChatOpenAI


client = AzureChatOpenAI(
    azure_endpoint = "https://oai-dio-bootcamp-dev-eastus-002-deonni.openai.azure.com/",
    api_key="eyydw6tDnETJj2SneGIeGk69TJKFcQAl73ZvRXSmUjEGbBLgAljWJQQJ99CAACHYHv6XJ3w3AAABACOGaU25",
    api_version="2024-02-15-preview",
    deployment_name="gpt-4o-mini",
    max_retries=0
)

def translate_article(text,lang):
  messages=[("system" , "Você atua como tradutor de textos"),
            ("user",f"traduza o {text} para o idioma {lang} e responda em markdown")
           ]
  response =client.invoke(messages)
  print(response.content)
  return response.content

translate_article("Let´s see if the deployment was suceeded","portugues")
# Out:
# Vamos ver se o deployment foi bem-sucedido.
# 'Vamos ver se o deployment foi bem-sucedido.'

# %%
url = "https://www.digitalocean.com/community/conceptual-articles/s-o-l-i-d-the-first-five-principles-of-object-oriented-design"
text= extract_text_from_url(url)
article = translate_article (text,"pt-br")
print(article)
# Out:
# # Princípios de Design SOLID Explicados: Construindo Melhores Arquiteturas de Software
#
# ## Introdução
# SOLID é um acrônimo para os cinco primeiros princípios de design orientado a objetos (OOD) propostos por Robert C. Martin (também conhecido como Uncle Bob). Apesar de esses princípios poderem ser aplicados a várias linguagens de programação, o código de exemplo contido neste artigo usará PHP. Esses princípios estabelecem práticas para o desenvolvimento de software com considerações para manutenção e extensão à medida que o projeto cresce. Adotar essas práticas pode ajudar a evitar cheiros de código, refatorar código e desenvolver software ágil ou adaptável.
#
# ### SOLID significa:
# - **S** - Princípio da Responsabilidade Única (Single Responsibility Principle)
# - **O** - Princípio Aberto-Fechado (Open-Closed Principle)
# - **L** - Princípio da Substituição de Liskov (Liskov Substitution Principle)
# - **I** - Princípio de Segregação de Interface (Interface Segregation Principle)
# - **D** - Princípio da Inversão de Dependência (Dependency Inversion Principle)
#
# Neste artigo, você será apresentado a cada princípio individualmente para entender como o SOLID pode ajudá-lo a se tornar um desenvolvedor melhor.
#
# ## Princípio da Responsabilidade Única
# O Princípio da Responsabilidade Única (SRP) afirma que uma classe deve ter uma e apenas uma razão para mudar, ou seja, uma classe deve ter apenas um trabalho.
#
# ### Exemplo:
# Considere um aplicativo que recebe uma coleção de formas — círculos e quadrados — e calcula a soma da área de todas as formas na coleção. Primeiramente, crie as classes de forma e configure os construtores para os parâmetros necessários.
#
# Para quadrados, você precisará saber o comprimento de um lado:
# ```php
# class Square
# {
#     public $length;
#     public function __construct($length)
#     {
#         $this->length = $length;
#     }
# }
# ```
# Para círculos, você precisará saber o raio:
# ```php
# class Circle
# {
#     public $radius;
#     public function __construct($radius)
#     {
#         $this->radius = $radius;
#     }
# }
# ```
# Em seguida, crie a classe `AreaCalculator` e escreva a lógica para somar as áreas de todas as formas fornecidas. A área de um quadrado é calculada pelo comprimento ao quadrado e a área de um círculo é calculada por pi vezes o raio ao quadrado.
#
# ```php
# class AreaCalculator
# {
#     protected $shapes;
#
#     public function __construct($shapes = [])
#     {
#         $this->shapes = $shapes;
#     }
#
#     public function sum()
#     {
#         $area = [];
#         foreach ($this->shapes as $shape) {
#             if (is_a($shape, 'Square')) {
#                 $area[] = pow($shape->length, 2);
#             } elseif (is_a($shape, 'Circle')) {
#                 $area[] = pi() * pow($shape->radius, 2);
#             }
#         }
#         return array_sum($area);
#     }
#
#     public function output()
#     {
#         return implode('', [
#             '',
#             'Soma das áreas das formas fornecidas: ',
#             $this->sum(),
#             '',
#         ]);
#     }
# }
# ```
# Para usar a classe `AreaCalculator`, você precisará instanciá-la, passar um array de formas e exibir a saída no final da página.
#
# ### Problemas com o SRP
# A classe `AreaCalculator`, como projetada acima, tem vários problemas em relação ao Princípio da Responsabilidade Única:
# - Ela calcula diretamente a área de cada forma específica dentro de seu método `sum()`. Isso significa que, se você introduzir uma nova forma (por exemplo, Triângulo), precisará modificar `AreaCalculator`. Isso viola o SRP.
# - Também manipula a saída de dados/apresentação dentro de seu método `output()`, que é uma preocupação separada da calculação.
#
# ### Aplicando o SRP em duas etapas
# #### Etapa 1: Dando responsabilidades próprias às formas
# Na verdade, em um design orientado a objetos alinhado com o SRP, a única responsabilidade de uma forma deve incluir conhecer suas próprias propriedades e como realizar operações intrinsecamente relacionadas a essas propriedades, como calcular sua própria área.
#
# Aqui está o método de área definido em `Square`:
# ```php
# class Square {
#     public $length;
#
#     public function __construct($length) {
#         $this->length = $length;
#     }
#
#     public function area() {
#         return pow($this->length, 2);
#     }
# }
# ```
# E aqui está o método de área definido em `Circle`:
# ```php
# class Circle {
#     public $radius;
#
#     public function __construct($radius) {
#         $this->radius = $radius;
#     }
#
#     public function area() {
#         return pi() * pow($this->radius, 2);
#     }
# }
# ```
#
# Agora, o método `sum()` para `AreaCalculator` pode ser reescrito para simplesmente pedir a cada forma sua área, sem conhecer a fórmula de cálculo específica.
#
# #### Etapa 2: Separando cálculo da saída
# Ainda após a Etapa 1, a classe `AreaCalculator` tem duas responsabilidades principais:
# - Calcular a soma das áreas: Essa é sua função matemática central.
# - Manipular a saída dos dados/apresentação.
#
# Para resolver isso, você pode criar uma nova classe `SumCalculatorOutputter` que trata da lógica necessária para saída de dados ao usuário:
# ```php
# class SumCalculatorOutputter
# {
#     protected $calculator;
#
#     public function __construct(AreaCalculator $calculator) {
#         $this->calculator = $calculator;
#     }
#
#     public function JSON() {
#         $data = [
#             'soma' => $this->calculator->sum(),
#         ];
#         return json_encode($data);
#     }
#
#     public function HTML() {
#         return implode('', [
#             '',
#             'Soma das áreas das formas fornecidas: ',
#             $this->calculator->sum(),
#             '',
#         ]);
#     }
# }
# ```
# Agora, a classe `AreaCalculator` tem uma única responsabilidade: calcular a soma das áreas e a `SumCalculatorOutputter` tem a responsabilidade única de formatar e apresentar os resultados do cálculo.
#
# ## Princípio Aberto-Fechado
# O Princípio Aberto-Fechado (OCP) afirma que os objetos ou entidades devem ser abertos para extensão, mas fechados para modificação. Ou seja, uma classe deve ser extensível sem modificar a classe em si.
#
# ### Exemplo:
# Considerando a classe `AreaCalculator`, focamos no método `sum`:
# ```php
# class AreaCalculator
# {
#     protected $shapes;
#
#     public function __construct($shapes = []) {
#         $this->shapes = $shapes;
#     }
#
#     public function sum() {
#         foreach ($this->shapes as $shape) {
#             if (is_a($shape, 'Square')) {
#                 $area[] = pow($shape->length, 2);
#             } elseif (is_a($shape, 'Circle')) {
#                 $area[] = pi() * pow($shape->radius, 2);
#             }
#         }
#         return array_sum($area);
#     }
# }
# ```
# Se o usuário desejar incluir formas adicionais, como triângulos, pentágonos, hexágonos, etc., você teria que editar constantemente este arquivo, o que violaria o princípio aberto-fechado. Para melhorar o método `sum`, podemos remover a lógica para calcular a área e anexá-la a cada classe de forma.
#
# Adicionamos uma interface `ShapeInterface` que define o método `area` e modificamos nossas classes de forma para implementá-la.
#
# ```php
# interface ShapeInterface
# {
#     public function area();
# }
# ```
#
# ### Conclusão
# Você agora possui um entendimento sólido dos princípios SOLID. Esses não são apenas conceitos abstratos; são ferramentas poderosas para melhorar o design de seus sistemas orientados a objetos. A implementação consistente dos princípios SOLID resulta em um código mais manutenível, fácil de estender, simples de testar e menos propenso a quebras quando os requisitos mudam.
#
# Continue seu aprendizado explorando outros temas relacionados a práticas de design e desenvolvimento ágil.
#
# ## Perguntas Frequentes
# **1. O que são os 5 princípios SOLID na engenharia de software?**
# SOLID é um acrônimo que representa cinco princípios fundamentais de design orientado a objetos formulados por Robert C. Martin. Esses princípios são: SRP, OCP, LSP, ISP e DIP.
#
# **2. Por que o SOLID é importante na programação orientada a objetos?**
# Os princípios SOLID são importantes porque abordam desafios comuns no desenvolvimento de software, resultando em sistemas mais mantíveis, flexíveis e extensíveis.
#
# **3. Como aplico o Princípio da Responsabilidade Única?**
# Identifique responsabilidades distintas de uma classe e extraia essas responsabilidades em classes ou módulos separados, garantindo que cada nova entidade tenha apenas um motivo para mudar.
#
# **4. Como o Princípio Aberto-Fechado (OCP) é diferente do Princípio da Inversão de Dependência (DIP)?**
# O OCP foca na extensão comportamental sem modificação de código existente, enquanto o DIP foca na direção da dependência e abstração, promovendo um sistema onde módulos de alto nível e baixo nível dependem de abstrações.
#
# **5. Os princípios SOLID são apenas para OOP?**
# Embora os princípios SOLID tenham sido originalmente articulados no contexto da programação orientada a objetos, suas filosofias subjacentes se aplicam a boas práticas de design de software em geral, abrangendo diferentes paradigmas e escalas.
#
# Se você tiver mais dúvidas, sinta-se à vontade para perguntar!
# # Princípios de Design SOLID Explicados: Construindo Melhores Arquiteturas de Software
#
# ## Introdução
# SOLID é um acrônimo para os cinco primeiros princípios de design orientado a objetos (OOD) propostos por Robert C. Martin (também conhecido como Uncle Bob). Apesar de esses princípios poderem ser aplicados a várias linguagens de programação, o código de exemplo contido neste artigo usará PHP. Esses princípios estabelecem práticas para o desenvolvimento de software com considerações para manutenção e extensão à medida que o projeto cresce. Adotar essas práticas pode ajudar a evitar cheiros de código, refatorar código e desenvolver software ágil ou adaptável.
#
# ### SOLID significa:
# - **S** - Princípio da Responsabilidade Única (Single Responsibility Principle)
# - **O** - Princípio Aberto-Fechado (Open-Closed Principle)
# - **L** - Princípio da Substituição de Liskov (Liskov Substitution Principle)
# - **I** - Princípio de Segregação de Interface (Interface Segregation Principle)
# - **D** - Princípio da Inversão de Dependência (Dependency Inversion Principle)
#
# Neste artigo, você será apresentado a cada princípio individualmente para entender como o SOLID pode ajudá-lo a se tornar um desenvolvedor melhor.
#
# ## Princípio da Responsabilidade Única
# O Princípio da Responsabilidade Única (SRP) afirma que uma classe deve ter uma e apenas uma razão para mudar, ou seja, uma classe deve ter apenas um trabalho.
#
# ### Exemplo:
# Considere um aplicativo que recebe uma coleção de formas — círculos e quadrados — e calcula a soma da área de todas as formas na coleção. Primeiramente, crie as classes de forma e configure os construtores para os parâmetros necessários.
#
# Para quadrados, você precisará saber o comprimento de um lado:
# ```php
# class Square
# {
#     public $length;
#     public function __construct($length)
#     {
#         $this->length = $length;
#     }
# }
# ```
# Para círculos, você precisará saber o raio:
# ```php
# class Circle
# {
#     public $radius;
#     public function __construct($radius)
#     {
#         $this->radius = $radius;
#     }
# }
# ```
# Em seguida, crie a classe `AreaCalculator` e escreva a lógica para somar as áreas de todas as formas fornecidas. A área de um quadrado é calculada pelo comprimento ao quadrado e a área de um círculo é calculada por pi vezes o raio ao quadrado.
#
# ```php
# class AreaCalculator
# {
#     protected $shapes;
#
#     public function __construct($shapes = [])
#     {
#         $this->shapes = $shapes;
#     }
#
#     public function sum()
#     {
#         $area = [];
#         foreach ($this->shapes as $shape) {
#             if (is_a($shape, 'Square')) {
#                 $area[] = pow($shape->length, 2);
#             } elseif (is_a($shape, 'Circle')) {
#                 $area[] = pi() * pow($shape->radius, 2);
#             }
#         }
#         return array_sum($area);
#     }
#
#     public function output()
#     {
#         return implode('', [
#             '',
#             'Soma das áreas das formas fornecidas: ',
#             $this->sum(),
#             '',
#         ]);
#     }
# }
# ```
# Para usar a classe `AreaCalculator`, você precisará instanciá-la, passar um array de formas e exibir a saída no final da página.
#
# ### Problemas com o SRP
# A classe `AreaCalculator`, como projetada acima, tem vários problemas em relação ao Princípio da Responsabilidade Única:
# - Ela calcula diretamente a área de cada forma específica dentro de seu método `sum()`. Isso significa que, se você introduzir uma nova forma (por exemplo, Triângulo), precisará modificar `AreaCalculator`. Isso viola o SRP.
# - Também manipula a saída de dados/apresentação dentro de seu método `output()`, que é uma preocupação separada da calculação.
#
# ### Aplicando o SRP em duas etapas
# #### Etapa 1: Dando responsabilidades próprias às formas
# Na verdade, em um design orientado a objetos alinhado com o SRP, a única responsabilidade de uma forma deve incluir conhecer suas próprias propriedades e como realizar operações intrinsecamente relacionadas a essas propriedades, como calcular sua própria área.
#
# Aqui está o método de área definido em `Square`:
# ```php
# class Square {
#     public $length;
#
#     public function __construct($length) {
#         $this->length = $length;
#     }
#
#     public function area() {
#         return pow($this->length, 2);
#     }
# }
# ```
# E aqui está o método de área definido em `Circle`:
# ```php
# class Circle {
#     public $radius;
#
#     public function __construct($radius) {
#         $this->radius = $radius;
#     }
#
#     public function area() {
#         return pi() * pow($this->radius, 2);
#     }
# }
# ```
#
# Agora, o método `sum()` para `AreaCalculator` pode ser reescrito para simplesmente pedir a cada forma sua área, sem conhecer a fórmula de cálculo específica.
#
# #### Etapa 2: Separando cálculo da saída
# Ainda após a Etapa 1, a classe `AreaCalculator` tem duas responsabilidades principais:
# - Calcular a soma das áreas: Essa é sua função matemática central.
# - Manipular a saída dos dados/apresentação.
#
# Para resolver isso, você pode criar uma nova classe `SumCalculatorOutputter` que trata da lógica necessária para saída de dados ao usuário:
# ```php
# class SumCalculatorOutputter
# {
#     protected $calculator;
#
#     public function __construct(AreaCalculator $calculator) {
#         $this->calculator = $calculator;
#     }
#
#     public function JSON() {
#         $data = [
#             'soma' => $this->calculator->sum(),
#         ];
#         return json_encode($data);
#     }
#
#     public function HTML() {
#         return implode('', [
#             '',
#             'Soma das áreas das formas fornecidas: ',
#             $this->calculator->sum(),
#             '',
#         ]);
#     }
# }
# ```
# Agora, a classe `AreaCalculator` tem uma única responsabilidade: calcular a soma das áreas e a `SumCalculatorOutputter` tem a responsabilidade única de formatar e apresentar os resultados do cálculo.
#
# ## Princípio Aberto-Fechado
# O Princípio Aberto-Fechado (OCP) afirma que os objetos ou entidades devem ser abertos para extensão, mas fechados para modificação. Ou seja, uma classe deve ser extensível sem modificar a classe em si.
#
# ### Exemplo:
# Considerando a classe `AreaCalculator`, focamos no método `sum`:
# ```php
# class AreaCalculator
# {
#     protected $shapes;
#
#     public function __construct($shapes = []) {
#         $this->shapes = $shapes;
#     }
#
#     public function sum() {
#         foreach ($this->shapes as $shape) {
#             if (is_a($shape, 'Square')) {
#                 $area[] = pow($shape->length, 2);
#             } elseif (is_a($shape, 'Circle')) {
#                 $area[] = pi() * pow($shape->radius, 2);
#             }
#         }
#         return array_sum($area);
#     }
# }
# ```
# Se o usuário desejar incluir formas adicionais, como triângulos, pentágonos, hexágonos, etc., você teria que editar constantemente este arquivo, o que violaria o princípio aberto-fechado. Para melhorar o método `sum`, podemos remover a lógica para calcular a área e anexá-la a cada classe de forma.
#
# Adicionamos uma interface `ShapeInterface` que define o método `area` e modificamos nossas classes de forma para implementá-la.
#
# ```php
# interface ShapeInterface
# {
#     public function area();
# }
# ```
#
# ### Conclusão
# Você agora possui um entendimento sólido dos princípios SOLID. Esses não são apenas conceitos abstratos; são ferramentas poderosas para melhorar o design de seus sistemas orientados a objetos. A implementação consistente dos princípios SOLID resulta em um código mais manutenível, fácil de estender, simples de testar e menos propenso a quebras quando os requisitos mudam.
#
# Continue seu aprendizado explorando outros temas relacionados a práticas de design e desenvolvimento ágil.
#
# ## Perguntas Frequentes
# **1. O que são os 5 princípios SOLID na engenharia de software?**
# SOLID é um acrônimo que representa cinco princípios fundamentais de design orientado a objetos formulados por Robert C. Martin. Esses princípios são: SRP, OCP, LSP, ISP e DIP.
#
# **2. Por que o SOLID é importante na programação orientada a objetos?**
# Os princípios SOLID são importantes porque abordam desafios comuns no desenvolvimento de software, resultando em sistemas mais mantíveis, flexíveis e extensíveis.
#
# **3. Como aplico o Princípio da Responsabilidade Única?**
# Identifique responsabilidades distintas de uma classe e extraia essas responsabilidades em classes ou módulos separados, garantindo que cada nova entidade tenha apenas um motivo para mudar.
#
# **4. Como o Princípio Aberto-Fechado (OCP) é diferente do Princípio da Inversão de Dependência (DIP)?**
# O OCP foca na extensão comportamental sem modificação de código existente, enquanto o DIP foca na direção da dependência e abstração, promovendo um sistema onde módulos de alto nível e baixo nível dependem de abstrações.
#
# **5. Os princípios SOLID são apenas para OOP?**
# Embora os princípios SOLID tenham sido originalmente articulados no contexto da programação orientada a objetos, suas filosofias subjacentes se aplicam a boas práticas de design de software em geral, abrangendo diferentes paradigmas e escalas.
#
# Se você tiver mais dúvidas, sinta-se à vontade para perguntar!
